# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmetFarukBilgin/AhmetFarukBilgin.io/blob/main/Translate_UCI_Try2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pdfplumber
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 979.4 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 84.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 72.7 MB/s eta 0:00:00

# %%
import os
os.listdir()
import pdfplumber

# %%
#PDF → SAYFA BAZLI HAM METİN
pages_text = []

with pdfplumber.open("UCI_MTB_Rules_-_Part_IV_-_Rule_Changes_on_01.01.2026_-_ENG.pdf") as pdf:
    for i, page in enumerate(pdf.pages):
        text = page.extract_text()
        if text:
            pages_text.append({
                "page": i + 1,
                "text": text
            })

print("Toplam sayfa:", len(pages_text))
print("\n--- ÖRNEK SAYFA ---\n")
print(pages_text[0]["text"][:1000])
# Out:
# Toplam sayfa: 50
#
# --- ÖRNEK SAYFA ---
#
# MEMORANDUM
# 06.10.2025
# PART 4 MOUNTAIN BIKE
# Rules amendments applying on 01.01.2026
# Chapter I GENERAL RULES
# § 2 Age categories and participation
# Cross-country Olympic – XCO
# 4.1.004 Except in the UCI World Championships, Continental Championships, UCI Mountain
# Bike Continental Series and, at the discretion of national federations, National
# Championships, under 23 men and women can ride the events for elite men and women
# respectively, even if a separate event is being run for under 23 riders.
# Separate under 23 XCO UCI World Cup events are organised for men and women. The
# first 5 men under 23 and the first 5 women under 23 of the last UCI XCO individual
# ranking of the preceding year can decide whether they want to race the entire UCI World
# Cup season as elite or under 23. All other under 23 riders must race the UCI World Cup
# season in the under 23 category. Riders benefitting from the injury status should decide
# whether they want to race the entire UCI World Cup season as elite or under 23

# %%
#HAM METNİ BİRLEŞTİR (AMA HENÜZ PARÇALAMA YOK
raw_text = "\n".join(p["text"] for p in pages_text)

print(raw_text[:1500])
# Out:
# MEMORANDUM
# 06.10.2025
# PART 4 MOUNTAIN BIKE
# Rules amendments applying on 01.01.2026
# Chapter I GENERAL RULES
# § 2 Age categories and participation
# Cross-country Olympic – XCO
# 4.1.004 Except in the UCI World Championships, Continental Championships, UCI Mountain
# Bike Continental Series and, at the discretion of national federations, National
# Championships, under 23 men and women can ride the events for elite men and women
# respectively, even if a separate event is being run for under 23 riders.
# Separate under 23 XCO UCI World Cup events are organised for men and women. The
# first 5 men under 23 and the first 5 women under 23 of the last UCI XCO individual
# ranking of the preceding year can decide whether they want to race the entire UCI World
# Cup season as elite or under 23. All other under 23 riders must race the UCI World Cup
# season in the under 23 category. Riders benefitting from the injury status should decide
# whether they want to race the entire UCI World Cup season as elite or under 23 if they
# were amongst the top 5 men under 23 or top 5 women under 23 of the last UCI XCO
# individual ranking before injury.
# Separate under 23 XCO hors class and class 1 events may be organized for men and
# women, in this case separate results must be submitted for both categories. A rider can
# only race in one category in the same competition. During class 2 and class 3 XCO
# events under 23, men and women, will compete with the elite categories. As such no
# separate results must be submitted for the

# %%
#İLK TEMİZLİK (ÇOK HAFİF)
clean_lines = []

for line in raw_text.split("\n"):
    line = line.strip()
    if not line:
        continue
    if len(line) < 5:
        continue
    clean_lines.append(line)

clean_text = " ".join(clean_lines)

print(clean_text[:1500])
# Out:
# MEMORANDUM 06.10.2025 PART 4 MOUNTAIN BIKE Rules amendments applying on 01.01.2026 Chapter I GENERAL RULES § 2 Age categories and participation Cross-country Olympic – XCO 4.1.004 Except in the UCI World Championships, Continental Championships, UCI Mountain Bike Continental Series and, at the discretion of national federations, National Championships, under 23 men and women can ride the events for elite men and women respectively, even if a separate event is being run for under 23 riders. Separate under 23 XCO UCI World Cup events are organised for men and women. The first 5 men under 23 and the first 5 women under 23 of the last UCI XCO individual ranking of the preceding year can decide whether they want to race the entire UCI World Cup season as elite or under 23. All other under 23 riders must race the UCI World Cup season in the under 23 category. Riders benefitting from the injury status should decide whether they want to race the entire UCI World Cup season as elite or under 23 if they were amongst the top 5 men under 23 or top 5 women under 23 of the last UCI XCO individual ranking before injury. Separate under 23 XCO hors class and class 1 events may be organized for men and women, in this case separate results must be submitted for both categories. A rider can only race in one category in the same competition. During class 2 and class 3 XCO events under 23, men and women, will compete with the elite categories. As such no separate results must be submitted for the

# %%
def remove_headers_footers(text):
    text = re.sub(r"Page\s+\d+\s*/\s*\d+", "", text, flags=re.IGNORECASE)

    text = re.sub(
        r"Allée\s+Ferdi\s+Kübler\s+12.*?Switzerland",
        "",
        text,
        flags=re.IGNORECASE | re.DOTALL
    )

    text = re.sub(r"T:\s*\+?\d[\d\s]+", "", text)
    text = re.sub(r"E:\s*\S+@\S+", "", text)

    return text

# %%
#Madde bazlı parçalama
import re

# SADECE "4.x.xxx" UCI maddelerini böl
parts = re.split(r"(?=\n?4\.\d+\.\d{3}\b)", clean_text)

articles = []

for part in parts:
    part = part.strip()
    if re.match(r"4\.\d+\.\d{3}\b", part):
        articles.append(part)

print("Bulunan madde sayısı:", len(articles))
print("\n--- ÖRNEK MADDE ---\n")
for article in articles[:5]:
    print(article)
    print("/n")
# Out:
# Bulunan madde sayısı: 108
#
# --- ÖRNEK MADDE ---
#
# 4.1.004 Except in the UCI World Championships, Continental Championships, UCI Mountain Bike Continental Series and, at the discretion of national federations, National Championships, under 23 men and women can ride the events for elite men and women respectively, even if a separate event is being run for under 23 riders. Separate under 23 XCO UCI World Cup events are organised for men and women. The first 5 men under 23 and the first 5 women under 23 of the last UCI XCO individual ranking of the preceding year can decide whether they want to race the entire UCI World Cup season as elite or under 23. All other under 23 riders must race the UCI World Cup season in the under 23 category. Riders benefitting from the injury status should decide whether they want to race the entire UCI World Cup season as elite or under 23 if they were amongst the top 5 men under 23 or top 5 women under 23 of the last UCI XCO individual ranking before injury. Separate under 23 XCO hors class and class 1 events may be organized for men and women, in this case separate results must be submitted for both categories. A rider can only race in one category in the same competition. During class 2 and class 3 XCO events under 23, men and women, will compete with the elite categories. As such no separate results must be submitted for the under 23 categories at class 2 and class 3 XCO events. (text modified on 01.10.13; 01.01.22; 01.01.25; 01.01.26) Cross-country marathon – XCM
# /n
# 4.1.005 Cross-country marathon events are open to all riders aged 19 or over and include masters categories. No separate results must be submitted for the under 23 category. Masters categories shall be listed in a separate results. Cross-country short track – XCC Cross-country short circuit events are open to all riders aged 19 or over. At the UCI World Championships, (as from 2024) and UCI World Cup and Continental Championships, separate under 23 events are organized for men and women. For other events no separate results must be submitted for the under 23 or elite categories. Cross-country eliminator – XCE Cross-country eliminator events are open to all riders aged 17 or over. No separate results must be submitted for the junior, under 23 or elite categories. (text modified on 01.01.17; 01.01.20, 01.01.21; 01.01.23; 01.01.24; 01.01.26) Downhill – DH
# /n
# 4.1.006 Except for the UCI World Championships, UCI World Cup and UCI Mountain Bike Continental Series, downhill events are open to all riders aged 17 or over. At the UCI World Championships, at the UCI World Cup and at the UCI Mountain Bike Continental Series, separate junior events must be organized for men and women (aged 17 and 18). Separate results must be sent to the UCI. At the Continental Championships and at the National Championships, separate junior events may be organised for men and women (aged 17 and 18). In this case also, separate results must be sent to the UCI. For all other downhill events on the international calendar, the UCI points are awarded in relation to the riders’ time and not to their category. To ensure that this rule is correctly applied, only one combined result needs to be sent to the UCI. Comment: When a junior downhill rider would score the best time at the National Championships, (s)he must wear the elite jersey. The junior jersey is not awarded in this case. (text modified on 01.07.12; 01.10.13; 04.04.14; 01.01.17; 01.01.25; 01.01.26) § 3 Calendar
# /n
# 4.1.011 International mountain bike races are registered on the UCI international calendar in accordance with the following classification: A. Olympic Games (OG) : - No other international mountain bike event of cross-country (XC) may be organised during the mountain bike competition of the Olympic Games. B. UCI World Championships (CM): - No other international mountain bike event of the same format may be organised during the UCI World Championships. C. UCI World Cup (CDM): - No hors class, UCI Mountain Bike Continental Series or Class 1 event of the same format may be organised on the same continent on the same day as a UCI World Cup event. - The Continental Championships (CC) and National Championships (CN) in a format may not be organised during a UCI World Cup event in the same format. D. UCI Masters World Championships (CMM): E. Continental Championships (CC): Allée Ferdi Kübler 12 T: +41 24 468 58 11 Page 2 / 50 1860 Aigle E: admin@uci.ch Switzerland - No hors class, UCI Mountain Bike Continental Series or Class 1 event of the same format may be organised on the same continent on the same day as a Continental Championships. F. UCI Mountain Bike Continental Series (CS): - Upon consultation with the respective Continental Confederation, the UCI will appoint a certain number of events to be part of each UCI Mountain Bike Continental Series in accordance with the dedicated document publised by the UCI. - The competition name must be UCI Mountain Bike Continental Series followed by the event name. - No UCI Mountain Bike Continental Series may be organised during the UCI Mountain Bike World Championships, the UCI Mountain Bike World Cup or the Continental Championships of the same format on the same continent. G. Stage races: - Class: Hors Class (SHC) / Class 1 (S1) / Class 2 (S2); - No stage race Hors Class may be organised during the mountain bike competition of the Olympic Games, or the UCI World Championships cross-country (XC) or marathon, UCI World Cup events in the concerned continent. - No stage race, in HC or C1, may be organised during the Continental Championships of the same format on the same day(s) as any cross- country (XC) race, on the concerned continent. H. One day races: - Class: Hors Class (HC) / Class 1 (C1) / Class 2 (C2) / Class 3 (C3) I. UCI XCO junior series: - The UCI will appoint a certain number of UCI XCO junior series events every year in accordance with the dedicated document published by the J. National Championships: - National Championships cannot be run during the mountain bike competition at the Olympic Games, UCI World Championships or UCI World Cup of the same format and cannot be run during Continental Championships of the same format on the concerned continent. - Cross-country Olympic (XCO) or cross-country short track (XCC) National Championships cannot be run during an international mountain bike race. For all other formats, in the event a national championship is incorporated in an international mountain bike race, a rider can only receive points once. The riders with the sporting nationality of the national federation will receive the National Championships points according to their rank in the race (i.e. including all riders regardless of their sporting nationality) and other riders will receive the class event points according to their rank in the race. K. Regional Games (JR). The events status for stage races and one-day races are allocated to each event annually by the UCI on the basis of the commissaires race report from the preceding year and any other information at disposal of the UCI. A new event may only be given class 2 or 3 status in its first year. HC status can only be given with the following cumulative conditions: Allée Ferdi Kübler 12 T: +41 24 468 58 11 Page 3 / 50 1860 Aigle E: admin@uci.ch Switzerland - event registered for at least the last three years as C1 on the UCI International Calendar; - a separate under 23 race registered for both genders for XCO; - at  ...
# /n
# 4.1.036 The riders must undertake to respect nature and the environment throughout the course and must make sure that they do not pollute the course venue site. If a littering drop zone is implemented on the course, riders must use it and must abide by any instructions given in this respect. (text modified on 01.01.25; 01.01.26) § 10 UCI International Elite Number System
# /n

# %%
#Maddeleri alt parçalara bölme
def split_uci_article(article_text):
    article_text = article_text.strip()

    match = re.match(r"(4\.\d+\.\d{3})(.*)", article_text, re.S)
    if not match:
        print("⚠️ Madde ID bulunamadı")
        return [article_text]

    article_id = match.group(1)
    body = match.group(2)

    # Satır kırılımlarını temizle
    body = re.sub(r"\s*\n\s*", " ", body)

    sentences = re.split(r"(?<=\.)\s+", body)

    chunks = []
    for s in sentences:
        s = s.strip()
        if re.search(r"(Allée|Switzerland|T:|E:)", s):
            continue
        if len(s) > 20:
            chunks.append(f"{article_id} {s}")

    # DEBUG ÇIKTISI
    print(f"\n📌 {article_id} için {len(chunks)} parça bulundu:")
    for c in chunks:
        print("-", c)
        print()

    return chunks

# %%
split_uci_article(articles[0])
# Out:
# 📌 4.1.004 için 10 parça bulundu:
# - 4.1.004 Except in the UCI World Championships, Continental Championships, UCI Mountain Bike Continental Series and, at the discretion of national federations, National Championships, under 23 men and women can ride the events for elite men and women respectively, even if a separate event is being run for under 23 riders.
#
# - 4.1.004 Separate under 23 XCO UCI World Cup events are organised for men and women.
#
# - 4.1.004 The first 5 men under 23 and the first 5 women under 23 of the last UCI XCO individual ranking of the preceding year can decide whether they want to race the entire UCI World Cup season as elite or under 23.
#
# - 4.1.004 All other under 23 riders must race the UCI World Cup season in the under 23 category.
#
# - 4.1.004 Riders benefitting from the injury status should decide whether they want to race the entire UCI World Cup season as elite or under 23 if they were amongst the top 5 men under 23 or top 5 women under 23 of the last UCI XCO individual ranking before injury.
#
# - 4.1.004 Separate under 23 XCO hors class and class 1 events may be organized for men and women, in this case separate results must be submitted for both categories.
#
# - 4.1.004 A rider can only race in one category in the same competition.
#
# - 4.1.004 During class 2 and class 3 XCO events under 23, men and women, will compete with the elite categories.
#
# - 4.1.004 As such no separate results must be submitted for the under 23 categories at class 2 and class 3 XCO events.
#
# - 4.1.004 (text modified on 01.10.13; 01.01.22; 01.01.25; 01.01.26) Cross-country marathon – XCM
# ['4.1.004 Except in the UCI World Championships, Continental Championships, UCI Mountain Bike Continental Series and, at the discretion of national federations, National Championships, under 23 men and women can ride the events for elite men and women respectively, even if a separate event is being run for under 23 riders.',
#  '4.1.004 Separate under 23 XCO UCI World Cup events are organised for men and women.',
#  '4.1.004 The first 5 men under 23 and the first 5 women under 23 of the last UCI XCO individual ranking of the preceding year can decide whether they want to race the entire UCI World Cup season as elite or under 23.',
#  '4.1.004 All other under 23 riders must race the UCI World Cup season in the under 23 category.',
#  '4.1.004 Riders benefitting from the injury status should decide whether they want to race the entire UCI World Cup season as elite or under 23 if they were amongst the top 5 men under 23 or top 5 women under 23 of the last UCI XCO individual ranking before injury.',
#  '4.1.004 Separate under 23 XCO hors class and class 1 events may be organized for men and women, in this case separate results must be submitted for both categories.',
#  '4.1.004 A rider can only race in one category in the same competition.',
#  '4.1.004 During class 2 and class 3 XCO events under 23, men and women, will compete with the elite categories.',
#  '4.1.004 As such no separate results must be submitted for the under 23 categories at class 2 and class 3 XCO events.',
#  '4.1.004 (text modified on 01.10.13; 01.01.22; 01.01.25; 01.01.26) Cross-country marathon – XCM']

# %%
#CSV Export from chunks
import csv

all_chunks = []
counters = {}

for art in articles:
    chunks = split_uci_article(art)
    for ch in chunks:
        article_id = ch.split()[0]
        text = ch[len(article_id):].strip()

        counters.setdefault(article_id, 0)
        counters[article_id] += 1

        uid = f"{article_id}_{counters[article_id]}"
        all_chunks.append([uid, article_id, text])

with open("uci_rules_en_chunks.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["uid", "article_id", "source_en"])
    writer.writerows(all_chunks)

print("✅ CSV oluşturuldu: uci_rules_en_chunks.csv")
print("Toplam satır:", len(all_chunks))
# Out:
# 📌 4.1.004 için 10 parça bulundu:
# - 4.1.004 Except in the UCI World Championships, Continental Championships, UCI Mountain Bike Continental Series and, at the discretion of national federations, National Championships, under 23 men and women can ride the events for elite men and women respectively, even if a separate event is being run for under 23 riders.
#
# - 4.1.004 Separate under 23 XCO UCI World Cup events are organised for men and women.
#
# - 4.1.004 The first 5 men under 23 and the first 5 women under 23 of the last UCI XCO individual ranking of the preceding year can decide whether they want to race the entire UCI World Cup season as elite or under 23.
#
# - 4.1.004 All other under 23 riders must race the UCI World Cup season in the under 23 category.
#
# - 4.1.004 Riders benefitting from the injury status should decide whether they want to race the entire UCI World Cup season as elite or under 23 if they were amongst the top 5 men under 23 or top 5 women under 23 of the last UCI XCO individual ranking before injury.
#
# - 4.1.004 Separate under 23 XCO hors class and class 1 events may be organized for men and women, in this case separate results must be submitted for both categories.
#
# - 4.1.004 A rider can only race in one category in the same competition.
#
# - 4.1.004 During class 2 and class 3 XCO events under 23, men and women, will compete with the elite categories.
#
# - 4.1.004 As such no separate results must be submitted for the under 23 categories at class 2 and class 3 XCO events.
#
# - 4.1.004 (text modified on 01.10.13; 01.01.22; 01.01.25; 01.01.26) Cross-country marathon – XCM
#
#
# 📌 4.1.005 için 9 parça bulundu:
# - 4.1.005 Cross-country marathon events are open to all riders aged 19 or over and include masters categories.
#
# - 4.1.005 No separate results must be submitted for the under 23 category.
#
# - 4.1.005 Masters categories shall be listed in a separate results.
#
# - 4.1.005 Cross-country short track – XCC Cross-country short circuit events are open to all riders aged 19 or over.
#
# - 4.1.005 At the UCI World Championships, (as from 2024) and UCI World Cup and Continental Championships, separate under 23 events are organized for men and women.
#
# - 4.1.005 For other events no separate results must be submitted for the under 23 or elite categories.
#
# - 4.1.005 Cross-country eliminator – XCE Cross-country eliminator events are open to all riders aged 17 or over.
#
# - 4.1.005 No separate results must be submitted for the junior, under 23 or elite categories.
#
# - 4.1.005 (text modified on 01.01.17; 01.01.20, 01.01.21; 01.01.23; 01.01.24; 01.01.26) Downhill – DH
#
#
# 📌 4.1.006 için 10 parça bulundu:
# - 4.1.006 Except for the UCI World Championships, UCI World Cup and UCI Mountain Bike Continental Series, downhill events are open to all riders aged 17 or over.
#
# - 4.1.006 At the UCI World Championships, at the UCI World Cup and at the UCI Mountain Bike Continental Series, separate junior events must be organized for men and women (aged 17 and 18).
#
# - 4.1.006 Separate results must be sent to the UCI.
#
# - 4.1.006 At the Continental Championships and at the National Championships, separate junior events may be organised for men and women (aged 17 and 18).
#
# - 4.1.006 In this case also, separate results must be sent to the UCI.
#
# - 4.1.006 For all other downhill events on the international calendar, the UCI points are awarded in relation to the riders’ time and not to their category.
#
# - 4.1.006 To ensure that this rule is correctly applied, only one combined result needs to be sent to the UCI.
#
# - 4.1.006 Comment: When a junior downhill rider would score the best time at the National Championships, (s)he must wear the elite jersey.
#
# - 4.1.006 The junior jersey is not awarded in this case.
#
# - 4.1.006 (text modified on 01.07.12; 01.10.13; 04.04.14; 01.01.17; 01.01.25; 01.01.26) § 3 Calendar
#
#
# 📌 4.1.011 için 27 parça bulundu:
# - 4.1.011 International mountain bike races are registered on the UCI international calendar in accordance with the following classification: A.
#
# - 4.1.011 Olympic Games (OG) : - No other international mountain bike event of cross-country (XC) may be organised during the mountain bike competition of the Olympic Games.
#
# - 4.1.011 UCI World Championships (CM): - No other international mountain bike event of the same format may be organised during the UCI World Championships.
#
# - 4.1.011 UCI World Cup (CDM): - No hors class, UCI Mountain Bike Continental Series or Class 1 event of the same format may be organised on the same continent on the same day as a UCI World Cup event.
#
# - 4.1.011 - The Continental Championships (CC) and National Championships (CN) in a format may not be organised during a UCI World Cup event in the same format.
#
# - 4.1.011 UCI Masters World Championships (CMM): E.
#
# - 4.1.011 UCI Mountain Bike Continental Series (CS): - Upon consultation with the respective Continental Confederation, the UCI will appoint a certain number of events to be part of each UCI Mountain Bike Continental Series in accordance with the dedicated document publised by the UCI.
#
# - 4.1.011 - The competition name must be UCI Mountain Bike Continental Series followed by the event name.
#
# - 4.1.011 - No UCI Mountain Bike Continental Series may be organised during the UCI Mountain Bike World Championships, the UCI Mountain Bike World Cup or the Continental Championships of the same format on the same continent.
#
# - 4.1.011 Stage races: - Class: Hors Class (SHC) / Class 1 (S1) / Class 2 (S2); - No stage race Hors Class may be organised during the mountain bike competition of the Olympic Games, or the UCI World Championships cross-country (XC) or marathon, UCI World Cup events in the concerned continent.
#
# - 4.1.011 - No stage race, in HC or C1, may be organised during the Continental Championships of the same format on the same day(s) as any cross- country (XC) race, on the concerned continent.
#
# - 4.1.011 One day races: - Class: Hors Class (HC) / Class 1 (C1) / Class 2 (C2) / Class 3 (C3) I.
#
# - 4.1.011 UCI XCO junior series: - The UCI will appoint a certain number of UCI XCO junior series events every year in accordance with the dedicated document published by the J.
#
# - 4.1.011 National Championships: - National Championships cannot be run during the mountain bike competition at the Olympic Games, UCI World Championships or UCI World Cup of the same format and cannot be run during Continental Championships of the same format on the concerned continent.
#
# - 4.1.011 - Cross-country Olympic (XCO) or cross-country short track (XCC) National Championships cannot be run during an international mountain bike race.
#
# - 4.1.011 For all other formats, in the event a national championship is incorporated in an international mountain bike race, a rider can only receive points once.
#
# - 4.1.011 The riders with the sporting nationality of the national federation will receive the National Championships points according to their rank in the race (i.e.
#
# - 4.1.011 including all riders regardless of their sporting nationality) and other riders will receive the class event points according to their rank in the race.
#
# - 4.1.011 The events status for stage races and one-day races are allocated to each event annually by the UCI on the basis of the commissaires race report from the preceding year and any other information at disposal of the UCI.
#
# - 4.1.011 A new event may only be given class 2 or 3 status in its first year.
#
# - 4.1.011 Under exceptional circumstances and justified reasons related to development, the UCI can grant derogations awarding HC status to events which do not meet the criteria above.
#
# - 4.1.011 A detailed technical guide for HC events, stage races and new events must be presented to UCI during the calendar registration process.
#
# - 4.1.011 A template for such technical guide is provided by UCI upon request.
#
# - 4.1.011 All events registered on the UCI international calendar must respect the UCI financial obligations (in particular calendar fee, prize money) approved by the UCI and published on the UCI website.
#
# - 4.1.011 Race entry fees, including uplift facilities for downhill and enduro, for events on the international calendar are waived for any rider belonging to a UCI MTB WORLD SERIES TEAM.
#
# - 4.1.011 This applies only to the format in which the team has UCI MTB WORLD SERIES TEAM status and does not apply to stage races, eliminator and enduro events.
#
# - 4.1.011 (text modified on 01.02.12; 01.10.13; 04.04.14; 01.01.16; 01.01.17; 01.01.19; 01.01.21; 01.01.22; 01.01.23; 01.01.24; 01.01.25; 01.01.26) § 6 Event procedure
#
#
# 📌 4.1.036 için 3 parça bulundu:
# - 4.1.036 The riders must undertake to respect nature and the environment throughout the course and must make sure that they do not pollute the course venue site.
#
# - 4.1.036 If a littering drop zone is implemented on the course, riders must use it and must abide by any instructions given in this respect.
#
# - 4.1.036 (text modified on 01.01.25; 01.01.26) § 10 UCI International Elite Number System
#
#
# 📌 4.1.049 için 4 parça bulundu:
# - 4.1.049 Riders who have won an Elite UCI World Cup race (XCO, DHI, EDR) will be asked to select a unique career number (2-999) for the UCI Mountain Bike World Cup (XCO, DHI, EDR).
#
# - 4.1.049 Upon retirement being confirmed to the UCI or communicated publicly, a rider's unique career number will be made available for allocation to other riders.
#
# - 4.1.049 Elite riders will be asked to select their number in descending order starting with the rider who currently has the highest number of UCI World Cup wins.
#
# - 4.1.049 For the UCI World Cup, the current UCI World Cup leader will race with number 1, superseding his unique career number.
#
#
# 📌 4.2.010 için 1 parça bulundu:
# - 4.2.010 Course The course for a cross-country eliminator race must be between 500m and 1000 1200m and include natural and/or artificial obstacles, in conformity with article
#
#
# 📌 4.2.009 için 4 parça bulundu:
# - 4.2.009 The whole course must be 100% rideable, single track sections normally are avoided and where possible the course normally has not more than one 180° turn.
#
# - 4.2.009 The start and finish area must be separated in order to allow short race program.
#
# - 4.2.009 Obstacles such as trees, stairs (up/down), drops, bridges or wooden constructions can create a dynamic short race.
#
# - 4.2.009 The course must be marked according to articles
#
#
# 📌 4.2.020 için 0 parça bulundu:
#
# 📌 4.2.029 için 1 parça bulundu:
# - 4.2.029 The start/finish zones must be respected as per articles
#
#
# 📌 4.2.030 için 0 parça bulundu:
#
# 📌 4.2.034 için 2 parça bulundu:
# - 4.2.034 Apart from XCE UCI World Championships and XCE UCI World Cup, all other XCE events will be considered as Class 3 events.
#
# - 4.2.034 (text modified on 01.10.13; 04.04.14; 01.01.16; 01.01.21; 01.01.22; 01.01.26) § 5 Feed/Technical Assistance zone
#
#
# 📌 4.2.036 için 10 parça bulundu:
# - 4.2.036 Each feed/technical assistance zone must be located on flat or uphill sections which are slow and wide enough for the purpose.
#
# - 4.2.036 The zones must be long enough and reasonably evenly spaced around the course.
#
# - 4.2.036 Double feed/technical assistance zones are recommended.
#
# - 4.2.036 For cross-country short track (XCC) events, a feed/technical assistance zone is not allowed.
#
# - 4.2.036 For Olympic format cross-country events (XCO) at least 1 single feed/technical assistance zone shall be set up.
#
# - 4.2.036 For marathon format cross-country events (XCM) at least 3 feed/technical assistance zones shall be set up.
#
# - 4.2.036 Organisers must anticipate on the team staff access possibilities during cross-country marathon events.
#
# - 4.2.036 For the cross-country team relay event during the UCI World Championships and, if applicable, during the Continental Championships, a feed/technical assistance zone can be set up for technical support only, at the discretion of the president of the commissaires’ panel.
#
# - 4.2.036 For the sake of clarity, feeding from the feed/technical zone is not permitted for the cross-country team relay events.
#
# - 4.2.036 (text modified on 01.01.17; 01.01.23; 01.01.26)
#
#
# 📌 4.2.038 için 5 parça bulundu:
# - 4.2.038 The feed/technical assistance zones must be wide and long enough to allow the passing of riders not stopping in the zone.
#
# - 4.2.038 Should the riders take the pit lane for no valid reason, the commissaires may disqualify them.
#
# - 4.2.038 For UCI World Cup events they must furthermore include the following four two areas: - one part for UCI MTB WORLD SERIES TEAMS; - one part for all other groups respecting the order, UCI MTB Teams, National Federations, all others; - one part for UCI MTB TEAMS; - one area for national teams; - another area for individual riders or members of teams not registered with the UCI (who are treated as individual riders).
#
# - 4.2.038 Staff working for riders must wear readily identifiable team clothing.
#
# - 4.2.038 (text modified on 01.01.20; 01.01.23; 01.01.25; 01.01.26)
#
#
# 📌 4.2.040 için 7 parça bulundu:
# - 4.2.040 For the Olympic Games, UCI World Championships, UCI World Cup events and Continental Championships nobody may enter a feed/technical assistance zone without accreditation.
#
# - 4.2.040 This rule does not apply for the marathon UCI World Championships.
#
# - 4.2.040 For the Olympic Games, UCI World Championships and Continental Championships, accreditations are issued by the commissaires' panel.
#
# - 4.2.040 For UCI World Cup events season long accreditations are issued to the UCI MTB WORLD SERIES TEAMS and UCI MTB TEAMS by the UCI.
#
# - 4.2.040 For the national federations or individual riders passes are prepared by the organiser and handed out at registration: they obtain 1 accreditation per registered rider per zone.
#
# - 4.2.040 Note that for a double feed/technical assistance zone they only obtain 1 accreditation per registered rider.
#
# - 4.2.040 (text modified on 01.01.20; 01.01.23; 01.01.24; 01.01.25; 01.01.26)
#
#
# 📌 4.2.042 için 3 parça bulundu:
# - 4.2.042 The spraying of water on riders or bicycles by the feeders or mechanics is forbidden.
#
# - 4.2.042 High pressure washers are forbidden in the feed/technical assistance zone.
#
# - 4.2.042 (text modified on 01.01.26) § 7 Safety
#
#
# 📌 4.2.059 için 2 parça bulundu:
# - 4.2.059 The organiser must provide for cross-country marathon events a motorcycle to mark the front of the race (“lead bike”), and a motorcycle to mark the rear of the race ("sweep bike").
#
# - 4.2.059 For Olympic format events, only a lead bike must be provided and display on its front the number of laps remaining in the race.
#
#
# 📌 4.3.006 için 1 parça bulundu:
# - 4.3.006 The length of the course and the duration of the event are determined as follows: Minimum Maximum Course length 1500m 3500 m Duration of the event 2 minutes 5 minutes UCI World Class 2 events Class 3 Championships, UCI events World Cup, Continental Championships, UCI Mountain Bike Continental Series, Hors Class, class 1 events Minimum Maximum Minimum Maximum Duration 2 5 minutes 1 minute 5 minutes No of the minutes restriction event (text modified on 01.01.16; 01.01.25; 01.01.26)
#
#
# 📌 4.3.007 için 3 parça bulundu:
# - 4.3.007 The entire downhill course must be marked and protected with safe and visible course markers that present no safety risks to riders.
#
# - 4.3.007 No equipment outside the official Host Broadcaster or Timing Company’s equipment can be installed in the B zones by anybody.
#
# - 4.3.007 (text modified on 01.01.17; 01.01.19; 01.01.23; 01.01.24; 01.01.26) § 4 Marshals
#
#
# 📌 4.3.019 için 4 parça bulundu:
# - 4.3.019 Riders observing a waving red flag during the race must stop immediately.
#
# - 4.3.019 A stopped rider must continue calmly to the finish and request a re-start from the finish line commissaire and wait for further instruction.
#
# - 4.3.019 The re-run should take place before the end of the stopped rider’s category, when possible.
#
# - 4.3.019 (text modified on 01.01.26) § 6 Training
#
#
# 📌 4.3.021 için 8 parça bulundu:
# - 4.3.021 The following training sessions must be organised: - an on-foot inspection of the course must be organised before the first training session.
#
# - 4.3.021 No bikes are allowed on the course during the on foot downhill course inspection.
#
# - 4.3.021 The on-foot inspection is reserved exclusively for riders, the team managers and the coaches who must hold a valid license.
#
# - 4.3.021 Other team staff are not allowed to attend the on-foot inspection.
#
# - 4.3.021 - a training session, the day before competition.
#
# - 4.3.021 - a training session on the morning of the race day.
#
# - 4.3.021 No training is permitted whilst a race is in progress.
#
# - 4.3.021 (text modified on 01.01.20; 01.01.26) Chapter V ENDURO EVENTS (chapter reviewed on 01.01.26) § 1 Race characteristics
#
#
# 📌 4.5.001 için 10 parça bulundu:
# - 4.5.001 The race includes several liaison stages and timed stages.
#
# - 4.5.001 The times achieved in all timed stage will be accumulated to a total time.
#
# - 4.5.001 An enduro course comprises varied off-road terrain.
#
# - 4.5.001 The track should include a mixture of narrow and wide, slow and fast paths and tracks over a mixture of off-road surfaces.
#
# - 4.5.001 Each timed stage must be predominantly descending but small pedalling or uphill sections are acceptable.
#
# - 4.5.001 Stages must focus on testing the rider’s technical skills.
#
# - 4.5.001 chairlift), pedal powered climbs or a mixture of both.
#
# - 4.5.001 The emphasis of the track must be on rider enjoyment, technical and physical ability.
#
# - 4.5.001 Any other system may be acceptable only under exceptional circumstances and subject to prior authorisation from the UCI.
#
# - 4.5.001 (text modified on 01.01.26) § 2 Technical assistance
#
#
# 📌 4.5.002 için 8 parça bulundu:
# - 4.5.002 A technical assistance zone can be provided by the organizer.
#
# - 4.5.002 Riders are allowed to collect and drop equipment or food in the technical assistance zone.
#
# - 4.5.002 Outside technical assistance is only allowed in this area.
#
# - 4.5.002 Riders may access technical assistance whenever the official course route passes through the technical assistance zone.
#
# - 4.5.002 Riders seeking to leave the official course to return to the technical assistance zone for assistance must first seek approval from the race officials.
#
# - 4.5.002 This will incur a 3-minute penalty.
#
# - 4.5.002 Riders must then return to the racecourse at the point where they left.
#
# - 4.5.002 (text modified on 01.01.20; 01.01.26)
#
#
# 📌 4.5.003 için 4 parça bulundu:
# - 4.5.003 Only one frame, one front fork and one pair of wheels can be used by a competitor during a competition.
#
# - 4.5.003 Frame, fork and wheels will be individually marked by the officials before the start of the race and checked at the finish.
#
# - 4.5.003 Broken parts can eventually may be replaced upon approval with a 5 min penalty if approved by race official may be replaced after first seeking approval from the PCP or race director with the application of a 3- minute penalty if approved by race official.
#
# - 4.5.003 (text modified on 01.01.26) § 3 Equipment
#
#
# 📌 4.5.004 için 6 parça bulundu:
# - 4.5.004 Riders must wear a full-face helmet at all times during competition.
#
# - 4.5.004 This includes during both Liaison and Special Stages.
#
# - 4.5.004 If a rider dismounts and pushes their bike on a Liaison, they may remove the helmet.
#
# - 4.5.004 Whilst riding, the helmet must always be worn correctly with straps fastened.
#
# - 4.5.004 In very technical terrain or on courses that feature steep mountainsides or very high-speed trails, the organiser can specify in his particular rules that competitors must wear a full-face helmet (either fixed or detachable).
#
# - 4.5.004 In addition to the above, the UCI strongly recommends that riders wear the protections as indicated in art.
#
#
# 📌 4.3.013 için 4 parça bulundu:
# - 4.3.013 Only one frame, fork and one set of wheels can be used by a rider during a race.
#
# - 4.3.013 A rider may use different/unmarked equipment during Official Training.
#
# - 4.3.013 Equipment Marking Stickers must be applied on the rider’s right-hand side of the bike.
#
# - 4.3.013 - fork crown; - swingarm / rear triangle; - front triangle; - both wheel rims.
#
#
# 📌 4.5.006 için 4 parça bulundu:
# - 4.5.006 The entire enduro courses must be marked and protected with safe and visible course markers that present no safety risks to riders.
#
# - 4.5.006 Course markers installed on opposite sides of the course will create a gate, which riders must pass between.
#
# - 4.5.006 Gates can be used to clearly mark sections of the course that a rider must pass through.
#
# - 4.5.006 Missing a gate will be deemed as course cutting.
#
#
# 📌 4.5.007 için 8 parça bulundu:
# - 4.5.007 Extra care must be taken by the organiser to make sure that the course is clearly marked and no shortcuts are possible.
#
# - 4.5.007 Taking shortcuts on course to gain an advantage can damage both the environment and bring the sport of enduro mountain bike racing into disrepute.
#
# - 4.5.007 Where no defined trail exists, the organiser should mark the course to keep the riders on the intended racecourse.
#
# - 4.5.007 If a clear and defined trail exists, the organiser may choose to create gates.
#
# - 4.5.007 In this instance riders must ride the existing defined trail between gates and not look to leave the trail to take a short cut and gain an unfair advantage.
#
# - 4.5.007 Therefore, any rider trying to save time by intentionally choosing a line that lies outside of the marked, defined racecourse will be disqualified (DSQ).
#
# - 4.5.007 Any rider found damaging the course or altering a Special Stage without the UCI approval will be subject to a penalty including DSQ.
#
# - 4.5.007 (text modified on 01.01.26)
#
#
# 📌 4.5.009 için 5 parça bulundu:
# - 4.5.009 Road crossing and dangerous area must be marked on both sides.
#
# - 4.5.009 All wooden features (e.g.
#
# - 4.5.009 wall-rides or large bridges), especially those that are situated in compressions, turns or braking zones, should be covered adequately with an anti-slip surface material (e.g.
#
# - 4.5.009 Wire mesh & or anti slip paint).
#
# - 4.5.009 (text modified on 01.01.26) § 6 Organisation of competition
#
#
# 📌 4.5.010 için 11 parça bulundu:
# - 4.5.010 Official training must be scheduled by the organiser on all Special Stages before timed competition begins.
#
# - 4.5.010 Training on all Special Stages is strongly recommended but not mandatory.
#
# - 4.5.010 Following the official course release, all Special Stages are closed to riders until official training commences.
#
# - 4.5.010 Any rider found riding on a Special Stage outside of official training will be subject to penalty.
#
# - 4.5.010 Only competing riders with a number plate issued for that specific race attached to their bike will be allowed on course during official training.
#
# - 4.5.010 In addition, officials, team staff and media will also be allowed access providing they display the relevant officially issued plates.
#
# - 4.5.010 A maximum of one training run is allowed per Special Stage.
#
# - 4.5.010 Unless otherwise agreed, official training should not take place more than two days prior to the start of the race.
#
# - 4.5.010 During official training times, riders must only access a Special Stage from the start and are not permitted to push up within the course or create congestion.
#
# - 4.5.010 Riders may push up outside of the course marking.
#
# - 4.5.010 (article introduced on 01.01.26)
#
#
# 📌 4.5.011 için 2 parça bulundu:
# - 4.5.011 The organiser must provide the start times for each timed stage.
#
# - 4.5.011 (text modified on 01.01.26)
#
#
# 📌 4.5.012 için 24 parça bulundu:
# - 4.5.012 Each rider takes an individual start, the start interval between the riders must be of 10 seconds at least.
#
# - 4.5.012 Riders must present themselves at the start line in time for their preassigned stage start time.
#
# - 4.5.012 All Special Stages will have a check-in point close to, but before the Special Stage start line.
#
# - 4.5.012 Riders must pass through this check-in point to record a check-in time.
#
# - 4.5.012 The check- in time may be used by Race Control to provide additional evidence of a rider’s arrival time at a Special Stage start in case of any delay or dispute around stage start time.
#
# - 4.5.012 All late riders must start only under instructions from the official starter, who will determine a suitable gap in the start order.
#
# - 4.5.012 No fixed start interval will be applied between late starters as the goal is to keep late riders in the competition, without affecting other riders.
#
# - 4.5.012 In cases where the late starter is delayed further due to insufficient gaps in the start order, penalties will be calculated based on a rider’s check-in time.
#
# - 4.5.012 If a rider fails to check- in, the penalty will be based on their Special Stage start time.
#
# - 4.5.012 Late starters will receive a fixed penalty: - up to 5 minutes late = 1-minute penalty; - 5+ minutes late = 5-minute penalty; - 30+ minutes late = DNF.
#
# - 4.5.012 Any rider arriving at the start of a Special Stage later than 30 minutes after their specified start time will be assigned a DNF for the race and will not be allowed to continue.
#
# - 4.5.012 Start Penalties Riders must start from a stationary position with their front wheel on the start line.
#
# - 4.5.012 Run up starts are not permitted.
#
# - 4.5.012 Any rider starting before the starter’s orders may be subject to a penalty.
#
# - 4.5.012 Other Start Violations (example: pushing into queue, delaying start, jumping start etc.) may also be subject to penalty.
#
# - 4.5.012 Delays Any delay applied to Special Stage start times must be maintained throughout that day of racing.
#
# - 4.5.012 Commissaires must not attempt to catch up on delays while racing is underway.
#
# - 4.5.012 If there is a 10-minute course hold on Special Stage 1, 10 minutes must be added to the start times of all remaining Special Stages, for all riders effected by the hold, for the remainder of the race.
#
# - 4.5.012 Disrupted race stage.
#
# - 4.5.012 In the event of a rider being delayed on a Special Stage due to assisting another rider in a medical emergency or due to some other circumstance outside of their control, such as a race hold on that Special Stage, and only if Race Control decide it is appropriate, a rider may be offered a re-run on that Special Stage.
#
# - 4.5.012 If Race Control deem that a re-run of the Special Stage in question is not possible then at the end of the race the rider will be allocated an “average” Special Stage position and time.
#
# - 4.5.012 This will be calculated as follows: Race control will take the rider’s actual finishing position across all Special Stages completed, minus his worst stage result and using this calculate their average stage finishing position.
#
# - 4.5.012 This average Special Stage position will then be awarded for the incomplete stage.
#
# - 4.5.012 (text modified on 01.01.26)
#
#
# 📌 4.5.013 için 3 parça bulundu:
# - 4.5.013 A minimum of 3 and a maximum of 10 timed stages must be raced over one or two days.
#
# - 4.5.013 The total time for each rider shall correspond to a minimum of 10 minutes.
#
# - 4.5.013 (text modified on 01.01.26)
#
#
# 📌 4.5.014 için 4 parça bulundu:
# - 4.5.014 A minimum of 2 different courses for the timed stages must be used.
#
# - 4.5.014 Under unforeseen and exceptional circumstances (e.g.
#
# - 4.5.014 weather), the UCI commissaire may, after consulting the organiser, cancel a stage or remove it from the general classification.
#
# - 4.5.014 (text modified on 01.01.26)
#
#
# 📌 4.5.015 için 3 parça bulundu:
# - 4.5.015 There are no restrictions on the nature of liaison stages.
#
# - 4.5.015 Uplift of riders can be either by mechanical means (chairlift, truck etc) or by pedalling or a mixture of both.
#
# - 4.5.015 (text modified on 01.01.26)
#
#
# 📌 4.5.016 için 2 parça bulundu:
# - 4.5.016 Adequate training must be provided by the organiser for all timed stages.
#
# - 4.5.016 (text modified on 01.01.26)
#
#
# 📌 4.5.017 için 4 parça bulundu:
# - 4.5.017 The transport of riders between Special Stages by private/team transport (shuttling) is strictly limited to official training and may be used only when an official rider shuttle provided by the organiser operates on the same route.
#
# - 4.5.017 Any rider found using a private or team vehicle at any other time or on any other route may be subject to penalties.
#
# - 4.5.017 Any venue specific details or restrictions on shuttling will be outlined in the Race Book and the official training schedule.
#
# - 4.5.017 During the race, no private/team transport can be used at any time.
#
#
# 📌 4.5.018 için 4 parça bulundu:
# - 4.5.018 The events General Classification will be calculated by adding all Special Stage times together for each rider.
#
# - 4.5.018 In the event of a tie in the General Classification, the highest placed rider on the final Special Stage will be awarded the higher final placing.
#
# - 4.5.018 A rider not finishing a Special Stage will not be allowed to rejoin the race at any time.
#
# - 4.5.018 (text modified on 01.01.26) § 6 Infringements
#
#
# 📌 4.5.019 için 2 parça bulundu:
# - 4.5.019 A rider must act in a sporting manner at all times and must permit any faster rider to overtake without obstructing.
#
# - 4.5.019 (text modified on 01.01.26)
#
#
# 📌 4.5.020 için 2 parça bulundu:
# - 4.5.020 The president of the commissaries’ panel can consider a rule violation that has not been witnessed by a race official if it has been reported by at least two riders who are part of two different teams (e.g.
#
# - 4.5.020 rider getting assistance outside technical assistance zone, rider cutting course) (text modified on 01.01.26) § 9 Marshals
#
#
# 📌 4.5.021 için 1 parça bulundu:
# - 4.5.021 For marshals, refer to the articles
#
#
# 📌 4.1.017 için 0 parça bulundu:
#
# 📌 4.1.021 için 3 parça bulundu:
# - 4.1.021 A small number of special trained marshals or commissaires should move around the course during competition to undisclosed points.
#
# - 4.1.021 Quad bike can be used to check rules infringements.
#
# - 4.1.021 (text modified on 01.01.26) § 10 Medical service
#
#
# 📌 4.5.022 için 1 parça bulundu:
# - 4.5.022 For first aid (minimum requirements), refer to the articles
#
#
# 📌 4.2.052 için 0 parça bulundu:
#
# 📌 4.2.059 için 2 parça bulundu:
# - 4.2.059 The organizer must set up an adequate medical service.
#
# - 4.2.059 The organizer must supply each competitor with emergency contact details.
#
#
# 📌 4.7.004 için 1 parça bulundu:
# - 4.7.004 The protective accessories are recommended mandatory to all competitors according to articles
#
#
# 📌 4.3.012 için 0 parça bulundu:
#
# 📌 4.3.013 için 1 parça bulundu:
# - 4.3.013 (text modified on 01.01.26) Chapter X UCI MOUNTAIN BIKE CROSS-COUNTRY WORLD CUP Participation
#
#
# 📌 4.10.001 için 19 parça bulundu:
# - 4.10.001 UCI Cross-country World Cup events (XCO and XCC) are open to riders meeting the following categories and criteria: Category One of the below mentioned criteria needs to be fulfilled XCO - men elite (aged 23 and over) 1.
#
# - 4.10.001 UCI MTB WORLD SERIES TEAM, maximum 4 riders XCO - women elite (aged 23 and per race and category over) 2.
#
# - 4.10.001 Maximum 8 UCI MTB TEAM wildcards, maximum 4 riders per race and category decided one month prior the event 3.
#
# - 4.10.001 Any rider ranked in the top 100 of the last UCI XCO individual ranking before the event entry closing date (one month prior to the event) 4.
#
# - 4.10.001 The national federations may enter a maximum of 3 supplementary riders per category.
#
# - 4.10.001 These riders must wear national team clothing.
#
# - 4.10.001 Top five three riders of any round of a UCI Mountain Bike Continental Series, limited to 1 round of the current UCI MTB World Cup within 52 weeks of the qualification (Golden Ticket) Not applicable for riders member of a UCI MTB WORLD SERIES TEAM 6.
#
# - 4.10.001 Top five riders from the final standings of any of the UCI Mountain Bike Continental Series of the previous year, Elite (from 2026) Not applicable for riders member of a UCI MTB WORLD SERIES TEAM 7.
#
# - 4.10.001 Top five riders from the final standings of any of the UCI Mountain Bike Continental Series of the previous year, U23 (if progressing into Elite category) (from 2026) Not applicable for riders member of a UCI MTB WORLD SERIES TEAM 8.
#
# - 4.10.001 Current Olympic Champion, UCI World Champion, Continental Champions, National Champions XCO - men under 23 (aged from 19 to 1.
#
# - 4.10.001 Maximum 8 UCI MTB TEAM wildcards, maximum 4 to 22) riders per race and category decided one month prior to the event 3.
#
# - 4.10.001 Any rider ranked in the top 200 of the last UCI XCO individual ranking before the event entry closing date (one month prior to the event) 4.
#
# - 4.10.001 The national federations may enter a maximum of 4 supplementary riders per category.
#
# - 4.10.001 These riders must wear national team clothing.
#
# - 4.10.001 Top five three riders of any round of a UCI Mountain Bike Continental Series, limited to 1 round of the current UCI MTB World Cup within 52 weeks of the qualification (Golden Ticket) Not applicable for riders member of a UCI MTB WORLD SERIES TEAM 6.
#
# - 4.10.001 Top five riders from the final standings of any of the UCI Mountain Bike Continental Series of the previous year, U23 (from 2026) Not applicable for riders member of a UCI MTB WORLD SERIES TEAM 7.
#
# - 4.10.001 Top five riders from the final standings of any of the UCI Mountain Bike Continental Series of the previous year, Junior (if progressing into U23 category) (from 2026) Not applicable for riders member of a UCI MTB WORLD SERIES TEAM 8.
#
# - 4.10.001 UCI World Champion, Continental Champions, National Champions XCC – men elite (aged 23 and over) A maximum of 40 Riders per gender already registered XCC – women elite (aged 23 and and confirmed for the XCO event taking place during the over) same weekend shall be allowed to start in the XCC event.
#
# - 4.10.001 XCC – men under 23 (aged from 19 to The riders shall be selected as per article
#
#
# 📌 4.10.003 için 2 parça bulundu:
# - 4.10.003 , points 22) 1 and 2, to reach a total number of 40 riders per gender.
#
# - 4.10.003 XCC – women under 23 (aged from On top of those 40 riders, wild cards can be awarded as 19 to 22) per article
#
#
# 📌 4.10.003 için 8 parça bulundu:
# - 4.10.003 No online registration is required for the XCC event.
#
# - 4.10.003 The same bike must be used for XCC and XCO.
#
# - 4.10.003 For XCC, the minimum tyre width must be 45mm.
#
# - 4.10.003 Registration Riders registration can be done only by a UCI MTB WORLD SERIES TEAM, a UCI MTB TEAM or a national federation.
#
# - 4.10.003 If a rider that confirmed his participation to the XCC event is not starting, he will not be allowed to start the XCO event on the same world cup round unless if the rider has been declared incapable medically unfit to of taking the start of the XCC event by the organiser’s chief medical officer or the team doctor.
#
# - 4.10.003 The rider must then be declared medically fit prior to starting the XCO, no later than 2 hours prior to the race start time.
#
# - 4.10.003 Prior to making a decision, the UCI can request the production of information or documents to assess the criteria above.
#
# - 4.10.003 (text modified on 01.01.25; 01.01.26)
#
#
# 📌 4.10.003 için 6 parça bulundu:
# - 4.10.003 The start order is determined as follows: XCC men elite and women elite, XCC men under 23 and women under 23 1.
#
# - 4.10.003 riders ranked in the top 16 of the most recently published XCO UCI World Cup standings (not applicable for the first UCI World Cup round of the season); 2.
#
# - 4.10.003 as per the most recently published UCI XCO individual ranking; 3.
#
# - 4.10.003 riders ranked in below rankings, unless they are listed on the start order above: - top 10 of the UCI cyclo-cross individual ranking; - top 20 of the UCI road individual world ranking; The place 41st and after will be allocated following the rank of each rider, whatever the ranking: UCI cyclo-cross or UCI road world ranking.
#
# - 4.10.003 If two or three riders have the same ranking, they will be placed by drawing lots.
#
# - 4.10.003 Riders with injury status shall be integrated in the start order in accordance with article
#
#
# 📌 4.10.011 için 1 parça bulundu:
# - 4.10.011 Riders with pregnancy status shall be integrated in the start order in accordance with article
#
#
# 📌 4.10.012 için 7 parça bulundu:
# - 4.10.012 XCO men elite and women elite 1.
#
# - 4.10.012 the riders ranked in the top 24 of the XCC race of the same UCI World Cup round; 2.
#
# - 4.10.012 the place 25th to 32nd will be allocated as per the most recently published UCI XCO individual ranking; 3.
#
# - 4.10.012 If two or three riders have the same ranking, they will be placed by drawing lots.
#
# - 4.10.012 as per the most recently published UCI XCO individual ranking; 5.
#
# - 4.10.012 unclassified riders: by drawing lots.
#
# - 4.10.012 Riders with injury status shall be integrated in the start order in accordance with article
#
#
# 📌 4.10.011 için 1 parça bulundu:
# - 4.10.011 Riders with pregnancy status shall be integrated in the start order in accordance with article
#
#
# 📌 4.10.012 için 5 parça bulundu:
# - 4.10.012 XCO men under 23 and women under 23: 1.
#
# - 4.10.012 the riders ranked in the top 24 of the XCC race of the same UCI World Cup round; 2.
#
# - 4.10.012 as per the most recently published UCI XCO individual ranking; 3.
#
# - 4.10.012 unclassified riders; by drawing lots.
#
# - 4.10.012 Riders with injury status shall be integrated in the start order in accordance with article
#
#
# 📌 4.10.011 için 1 parça bulundu:
# - 4.10.011 Riders with pregnancy status shall be integrated in the start order in accordance with article
#
#
# 📌 4.10.012 için 1 parça bulundu:
# - 4.10.012 (text modified on 01.01.24; 01.01.25; 01.01.26) Official ceremony
#
#
# 📌 4.10.007 için 3 parça bulundu:
# - 4.10.007 The official ceremony takes place immediately after each race.
#
# - 4.10.007 Riders arriving later than 5 minutes after they finished their race are fined.
#
# - 4.10.007 The following riders must attend: - the first three riders in the elite XCO events; - the first three riders in the elite XCC events; - the leader of the elite UCI World Cup standings after the event in question (XCO, XCC); - the first three riders in the under 23 events (XCO, XCC); - the leader of the under 23 UCI World Cup standings after the event in question (XCO, XCC); - the team leading the team standings after the event in question (specified in article
#
#
# 📌 4.10.009 için 5 parça bulundu:
# - 4.10.009 ); - the team of the day.
#
# - 4.10.009 The first three riders in the race and the leader of the general classification of the UCI World Cup must attend the podium.
#
# - 4.10.009 The UCI Mountain Bike World Cup licensee shall award a trophy to the first three of the final classification of the UCI Mountain Bike World Cup in each category.
#
# - 4.10.009 N.B - Bicycles cannot be taken onto the podium.
#
# - 4.10.009 However, an area is provided in front of the podium to display the bicycle of the winner during the official ceremony.
#
#
# 📌 4.10.011 için 6 parça bulundu:
# - 4.10.011 If due to injury a rider took part in less than three rounds of the UCI World Cup in a season, the national federation and the team may apply to the UCI for recognition of injury status.
#
# - 4.10.011 An application must be received at the UCI in writing no later than October 30th of the disrupted season.
#
# - 4.10.011 A rider with injury status shall be integrated in the ranking that is used to determine the start list, with the number of points determined according to following calculation: the average points gained per round in which the rider took part multiplied by the number of rounds of the UCI World Cup season during which the rider was absent due to injury.
#
# - 4.10.011 In case the rider is no longer included in the UCI World Cup standings, his UCI ranking of the year n-2 on 31 December will be considered.
#
# - 4.10.011 Such benefit shall be limited to the first two rounds of the UCI World Cup in which the rider takes part during the following season.
#
# - 4.10.011 (text modified on 01.01.24; 01.01.26) Pregnancy status
#
#
# 📌 4.10.012 için 6 parça bulundu:
# - 4.10.012 If due to pregnancy a rider took part in less than three rounds of the UCI World Cup in a season, the national federation and the team may apply to the UCI for recognition of pregnancy status.
#
# - 4.10.012 An application must be received at the UCI in writing no later than December 31st of the disrupted season.
#
# - 4.10.012 A rider with pregnancy status shall be integrated in the ranking that is used to determine the start list, with the number of points determined according to following calculation: the average points gained per round in which the rider took part multiplied by the number of rounds of the UCI World Cup season during which the rider was absent due to pregnancy.
#
# - 4.10.012 In case the rider is no longer included in the UCI World Cup standings, his UCI ranking of the year n-2 on 31 December will be considered.
#
# - 4.10.012 Such benefit shall be limited to the first two rounds of the UCI World Cup in which the rider takes part during the following season.
#
# - 4.10.012 (article introduced on 01.01.24; text modified on 01.01.26) Chapter XI UCI MOUNTAIN BIKE DOWNHILL WORLD CUP Participation
#
#
# 📌 4.11.001 için 20 parça bulundu:
# - 4.11.001 UCI MTB WORLD SERIES TEAM, maximum 4 DHI - women elite (aged 19 and over) riders per race and category 2.
#
# - 4.11.001 Maximum 8 UCI MTB TEAM wildcard, maximum 4 riders per race and category decided one month prior to the event 3.
#
# - 4.11.001 Any rider ranked in the top 50 of the last UCI DHI individual ranking before the event entry closing date (one month prior to the event) 4.
#
# - 4.11.001 The national federations may enter a maximum of 3 supplementary riders per category.
#
# - 4.11.001 These riders must wear national team clothing.
#
# - 4.11.001 Top five three riders of any round of a UCI Mountain Bike Continental Series, limited to 1 round of the current UCI MTB World Cup within 52 weeks of the qualification (Golden Ticket) Not applicable for riders member of a UCI MTB WORLD SERIES TEAM 6.
#
# - 4.11.001 Top five riders from the final standings of any of the UCI Mountain Bike Continental Series of the previous year, Elite (from 2026) Not applicable for riders member of a UCI MTB WORLD SERIES TEAM 7.
#
# - 4.11.001 Top five riders from the final standings of any of the UCI Mountain Bike Continental Series of the previous year, Junior (if progressing into Elite category) (from 2026) Not applicable for riders member of a UCI MTB WORLD SERIES TEAM 8.
#
# - 4.11.001 Current UCI World Champion, Continental Champions, National Champions DHI - men junior (aged 17 and 18) 1.
#
# - 4.11.001 UCI MTB WORLD SERIES TEAM, maximum 4 DHI – women junior (aged 17 and 18) riders per race and category 2.
#
# - 4.11.001 Maximum 8 UCI MTB TEAM wildcard, maximum 4 riders per race and category decided one month prior the event 3.
#
# - 4.11.001 Any rider ranked in the top 100 of the last UCI DHI individual ranking before the event entry closing date (one month prior the event) 4.
#
# - 4.11.001 The national federations may enter a maximum of 4 supplementary riders per category.
#
# - 4.11.001 These riders must wear national team clothing.
#
# - 4.11.001 Top five three riders of any round of a UCI Mountain Bike Continental Series, limited to 1 round of the current UCI MTB World Cup within 52 weeks of the qualification Not applicable for riders member of a UCI MTB WORLD SERIES TEAM 6.
#
# - 4.11.001 Top five riders from the final standings of any of the UCI Mountain Bike Continental Series of the previous year, Cadet (if progressing into Junior category) (from 2026) Not applicable for riders member of a UCI MTB WORLD SERIES TEAM 8.
#
# - 4.11.001 Current UCI World Champion, Continental Champions, National Champions Registration Riders registration can be done only by a UCI MTB WORLD SERIES TEAM, a UCI MTB TEAM or a national federation.
#
# - 4.11.001 Wild card Criteria to award the maximum 8 UCI MTB TEAM wildcards (as per point 2 of the participation criteria) per event will be based on the: - UCI team ranking, current and previous season ; - profile of any individual riders; - UCI Team composition (multi-category, multi-gender); - profile of team sponsors (out of industry, global, etc.); - media profile of team (social media, etc.); - any injury issues during current or previous season; - anti-doping history; - home country of team; - UCI Mountain Bike Continental series team standing.
#
# - 4.11.001 Prior to making a decision, the UCI can request the production of information or documents to assess the criteria above.
#
# - 4.11.001 (text modified on 01.01.25; 01.01.26)
#
#
# 📌 4.11.004 için 6 parça bulundu:
# - 4.11.004 The start order for the qualifying rounds 1 is determined as follows: Men Elite, Women Elite: 1.
#
# - 4.11.004 riders ranked in the top 20 men and the top 10 women of the most recently published UCI World Cup standings (for the first event, as per the final world cup standings of the previous year), starting in reverse order.
#
# - 4.11.004 as per the most recently published UCI World Cup standings; 3.
#
# - 4.11.004 as per the most recently published UCI DHI individual ranking, starting in reverse order.
#
# - 4.11.004 unclassified riders: by drawing lots.
#
# - 4.11.004 Riders with injury status shall be integrated in the start order in accordance with article
#
#
# 📌 4.11.021 için 1 parça bulundu:
# - 4.11.021 Riders with pregnancy status shall be integrated in the start order in accordance with article
#
#
# 📌 4.11.022 için 8 parça bulundu:
# - 4.11.022 reverse order of qualifying round 1 results; 2.
#
# - 4.11.022 riders ranked in the top 20 men and the top 10 women of the most recently published UCI World Cup standings (for the first event, as per the final UCI World Cup standings of the previous year), that did not qualify via the qualifying round 1 will start before the top 10 riders from qualifying round 1, starting in reverse order.
#
# - 4.11.022 The start order for the qualifying rounds is determined as follows: Men Junior, Women Junior: 1.
#
# - 4.11.022 riders ranked in the top 20 men junior and the top 10 women junior of the most recently published UCI World Cup standings (not applicable for the first UCI world cup round of the season), starting in reverse order; 2.
#
# - 4.11.022 as per the most recently published UCI World Cup standings; 3.
#
# - 4.11.022 as per the most recently published UCI DHI individual ranking, starting in reverse order.
#
# - 4.11.022 unclassified riders: by drawing lots.
#
# - 4.11.022 Riders with injury status shall be integrated in the start order in accordance with article
#
#
# 📌 4.11.021 için 1 parça bulundu:
# - 4.11.021 (text modified on 01.01.24; 01.01.25; 01.01.26)
#
#
# 📌 4.11.009 için 3 parça bulundu:
# - 4.11.009 Two forerunners must be designated and be ready to run the course as indicated by the president of the commissaires' panel before the qualifying round and finals.
#
# - 4.11.009 The forerunners' bicycles must be fitted with handlebar numbers bearing the letters A and B.
#
# - 4.11.009 The closing rider, according to article
#
#
# 📌 4.11.008 için 3 parça bulundu:
# - 4.11.008 , must be fitted with the handlebar number bearing the letter C.
#
# - 4.11.008 Forerunners and closing rider must be at least aged 17 and a UCI license holder adequately insured.
#
# - 4.11.008 (text modified on 01.01.26) Official ceremony
#
#
# 📌 4.11.017 için 3 parça bulundu:
# - 4.11.017 The official ceremony takes place immediately after each race.
#
# - 4.11.017 Riders arriving later than 5 minutes after they finished their race are fined.
#
# - 4.11.017 The following riders must attend: - the first three riders in the elite events; - the leader of the elite UCI World Cup standings after the event in question; - the first three riders in the junior events; - the leader of the junior UCI World Cup standings after the event in question; - the team leading the team standings after the event in question (specified in article
#
#
# 📌 4.11.020 için 5 parça bulundu:
# - 4.11.020 ); - the team of the day.
#
# - 4.11.020 The first three riders in the race and the leader of the general classification of the UCI World Cup must attend the podium.
#
# ...
#
# - 4.13.012 In case the rider is no longer included in the UCI World Cup standings, his UCI ranking of the year n-2 on 31 December will be considered.
#
# - 4.13.012 Such benefit shall be limited to the first two rounds of the UCI World Cup in which the rider takes part during the following season.
#
# - 4.13.012 (article introduced on 01.01.26) Pregnancy status
#
#
# 📌 4.13.013 için 6 parça bulundu:
# - 4.13.013 If due to pregnancy a rider took part in less than three rounds of the UCI World Cup in a season, the national federation and the team may apply for recognition of pregnancy status.
#
# - 4.13.013 An application must be received at the UCI in writing no later than December 31st of the disrupted season.
#
# - 4.13.013 A rider with pregnancy status shall be integrated in the ranking that is used to determine the start list, with the number of points determined according to following calculation: the average points gained per round in which the rider took part multiplied by the number of rounds of the UCI World Cup season during which the rider was absent due to pregnancy.
#
# - 4.13.013 In case the rider is no longer included in the UCI World Cup standings, his UCI ranking of the year n-2 on 31 December will be considered.
#
# - 4.13.013 Such benefit shall be limited to the first two rounds of the UCI World Cup in which the rider takes part during the following season.
#
# - 4.13.013 (article introduced on 01.01.26) Chapter XIV UCI E-MOUNTAIN BIKE CROSS-COUNTRY WORLD CUP Official ceremony
#
#
# 📌 4.14.005 için 5 parça bulundu:
# - 4.14.005 The official ceremony takes place immediately after each race.
#
# - 4.14.005 Riders arriving later than 5 minutes after they finished their race are fined.
#
# - 4.14.005 The following riders must attend: - the first three riders in the elite events; - the leader of the elite UCI World Cup standings after the event in question.
#
# - 4.14.005 The UCI Mountain Bike World Cup licensee shall award a trophy to the first three of the final classification of the UCI Mountain Bike World Cup in each category.
#
# - 4.14.005 (article introduced on 01.01.26) Chapter XV UCI MOUNTAIN BIKE ELIMINATOR WORLD CUP Official ceremony
#
#
# 📌 4.15.005 için 6 parça bulundu:
# - 4.15.005 The official ceremony takes place immediately after each race.
#
# - 4.15.005 Riders arriving later than 5 minutes after they finished their race are fined.
#
# - 4.15.005 The following riders must attend: - the first three riders in the elite events; - the leader of the elite UCI World Cup standings after the event in question.
#
# - 4.15.005 The first three riders in the race and the leader of the general classification of the UCI World Cup must attend the podium.
#
# - 4.15.005 The UCI Mountain Bike World Cup licensee shall award a trophy to the first three of the final classification of the UCI Mountain Bike World Cup in each category.
#
# - 4.15.005 (article introduced on 01.01.26) Chapter XVI UCI MOUNTAIN BIKE RANKING
#
#
# 📌 4.16.002 için 2 parça bulundu:
# - 4.16.002 An individual ranking for men and one for women is drawn up for each of the following types of event: - UCI XCO individual ranking (elite and under 23 combined); - UCI XCO junior individual ranking; - UCI XCM individual ranking; - UCI DHI individual ranking; - UCI EDR individual ranking; - UCI 4X individual ranking.
#
# - 4.16.002 (text modified on 01.02.12; 01.01.21; 01.01.26)
#
#
# 📌 4.16.006 için 6 parça bulundu:
# - 4.16.006 A UCI endurance team ranking is calculated by adding the points of the 4 highest scoring riders of each team without making a distinction between men elite, men under 23, women elite and women under 23.
#
# - 4.16.006 A UCI marathon team ranking is calculated by adding the points of the 4 best placed men and the 4 best placed women of each UCI MTB TEAM in the UCI XCM individual ranking.
#
# - 4.16.006 Only the results of the finals are taken into account.
#
# - 4.16.006 A UCI enduro team ranking is calculated by adding the point of the 4 highest scored points of each team without making a distinction between men elite, men junior, women elite and women junior.
#
# - 4.16.006 Tied teams have their relative positions determined by the place of their best rider on the individual ranking.
#
# - 4.16.006 (text modified on 01.07.12; 01.01.17, 01.01.21; 01.01.23; 01.01.25; 01.01.26)
#
#
# 📌 4.16.007 için 2 parça bulundu:
# - 4.16.007 The number of points to be awarded is shown in the annexes.
#
# - 4.16.007 For the cross-country Olympic (XCO) ranking only the types of events that meet the criteria set out in articles
#
#
# 📌 4.2.001 için 0 parça bulundu:
#
# 📌 4.2.002 için 0 parça bulundu:
#
# 📌 4.2.008 için 0 parça bulundu:
#
# 📌 4.2.010 için 0 parça bulundu:
#
# 📌 4.2.011 için 0 parça bulundu:
#
# 📌 4.2.013 için 0 parça bulundu:
#
# 📌 4.2.015 için 1 parça bulundu:
# - 4.2.015 For the cross-country marathon (XCM) ranking only the types of events that meet the criteria set out in articles
#
#
# 📌 4.2.004 için 8 parça bulundu:
# - 4.2.004 and the general classification of stage races are eligible.
#
# - 4.2.004 No UCI point is awarded separately for the individual stages forming part of stage races.
#
# - 4.2.004 The downhill ranking is based purely on individual downhill events including enduro events.
#
# - 4.2.004 All enduro, snow bike and pump track events will be considered as class 3 events.
#
# - 4.2.004 The 4X ranking is calculated from 4X events.
#
# - 4.2.004 The Enduro ranking is calculated from Enduro events.
#
# - 4.2.004 All Regional Games events will be considered as Class 2 events.
#
# - 4.2.004 (text modified on 01.02.12; 01.10.13; 01.01.16; 01.01.19, 01.01.21; 01.01.26) Chapter XVII UCI MTB WORLD SERIES TEAMS § 1 Identity
#
#
# 📌 4.18.001 için 6 parça bulundu:
# - 4.18.001 A UCI MTB WORLD SERIES TEAM is an entity consisting of: - minimum 3 riders, maximum 10 riders for cross-country (endurance); - minimum 3 riders, maximum 10 riders for downhill or enduro (gravity); - minimum 3 riders, maximum 10 riders for mixed teams.
#
# - 4.18.001 They are employed and/or sponsored by the same entity, for the purpose to take part in mountain bike events on the International UCI calendar.
#
# - 4.18.001 Development Team A UCI MTB WORLD SERIES TEAM can link with a UCI MTB Team, to be defined as their “development team” and shall report such information to the UCI.
#
# - 4.18.001 UCI MTB WORLD SERIES TEAMS can select one rider per UCI World Cup event from their development team to compete at a UCI World Cup, within the maximum of 4 riders per race per category.
#
# - 4.18.001 Guest rider In addition, a UCI MTB WORLD SERIES TEAM will have the opportunity to request to the UCI for 1 rider to be able to race at two UCI World Cup events within the season in either Elite, Junior or under 23 categories, within the maximum of 4 riders per race per category.
#
# - 4.18.001 This can be done outside the transfer period.
#
#
# 📌 4.20.001 için 15 parça bulundu:
# - 4.20.001 Table of race incidents in accordance with article 12.4.001.
#
# - 4.20.001 Except if stated differently, the amounts mentioned in the table below are in Swiss Francs (CHF).
#
# - 4.20.001 Column 1 Column 2 Discipline Event Event Mountain Bike Olympic Games Other events Elite UCI World Championships UCI World Cup Continental Championships Hors Class UCI Mountain Bike Continental Series Race incidents 1.
#
# - 4.20.001 Appearance at the start of a race or Start refused Start refused stage with a bicycle that does not comply with the regulations 1.2.
#
# - 4.20.001 Use of a bicycle that does not comply Disqualification (DSQ) Disqualification (DSQ) with the regulations in a race 1.3.
#
# - 4.20.001 Use or presence of a bicycle that does Rider: disqualification (DSQ) Rider: disqualification (DSQ) not comply with article 1.3.010 (cf.
#
# - 4.20.001 Clothing, helmet and accessories 2.1 Presentation at the start with non- Start refused Start refused compliant clothing, helmet or accessories 2.2 Use of non-compliant clothing, helmet Disqualification (DSQ) Disqualification (DSQ) or accessories during an event 2.3 Rider at the start without mandatory Start refused Start refused helmet 2.4 Start with damaged or no regular Start refused Start refused helmet 2.5 Rider taking off mandatory helmet Disqualification (DSQ) Disqualification (DSQ) during the race Rider: Elimination or disqualification Rider: Elimination or disqualification 2.6 Use of forbidden onboard technology device Other team member: Exclusion Other team member: Exclusion 3.
#
# - 4.20.001 Deliberate deviation from the race Rider: 200 fine and elimination Rider: 100 fine and elimination route, attempting to be placed without having covered the entire race route by bicycle 5.
#
# - 4.20.001 Unintentional detour from the race route constituting an advantage ONE-DAY RACE Elimination Elimination STAGE RACE Time trial: 20’’ penalty Relegation (REL) to last place of the stage 6.
#
# - 4.20.001 Failure to respect the instructions of Rider: 30 50 to 100 fine Rider: 20 50 to 100 fine the race organisation or commissaires Other licence holder: 100 to 200 fine Other licence holder: 50 to 200 fine 7.
#
# - 4.20.001 Recrossing the finish line in the Rider: 30 50 fine Rider: warning direction of the race while still wearing a body number and/or transponder (chip) 8.
#
# - 4.20.001 Rider turn back on the course to reach Disqualification (DSQ) Disqualification (DSQ) Feed/Technical Assistance Zone 10.
#
# - 4.20.001 Rider failing to respect the rules for 100 fine 50 fine the start 11.
#
# - 4.20.001 Delayed or lapped rider continuing the Disqualification (DSQ) Disqualification (DSQ) race in breach of the regulations 13.
#
# - 4.20.001 Rider fails to return to the course as in Disqualification (DSQ) Disqualification (DSQ) art
#
#
# 📌 4.1.035 için 25 parça bulundu:
# - 4.1.035 Failure to display handlebar number 100 fine rider 50 fine rider during training 200 fine team 100 fine team 15.
#
# - 4.1.035 Identification frame number modified 100 fine 50 fine 16.
#
# - 4.1.035 Alter the course Disqualification (DSQ) – accreditation removed Disqualification (DSQ) – accreditation removed 17.
#
# - 4.1.035 Passing through a level crossing that Disqualification (DSQ) Disqualification (DSQ) is closed 18.
#
# - 4.1.035 Irregular sprint ONE-DAY RACE Relegation (REL) to the last place in the rider’s Relegation (REL) to the last place in the rider’s group or group or Disqualification (DSQ) at sole discretion of the Disqualification (DSQ) at sole discretion of the commissaires’ panel in case of serious cases commissaires’ panel in case of serious cases STAGE RACE 1st offence Relegation REL and 30” penalisation in the stage results.
#
# - 4.1.035 2nd offence Disqualification (DSQ) 19.
#
# - 4.1.035 Cutting the course – short cut, using the pit lane to gain advantage ONE-DAY RACE Disqualification (DSQ) or relegation (REL) Disqualification (DSQ) or relegation (REL) depending on the length of the cut depending on the length of the cut STAGE RACE 2’-5’ penalisation in the stage results (or a time major to the gained advantage) 21.
#
# - 4.1.035 Failure to wear the race leader’s jersey ONE-DAY RACE 1st offence 250 fine 1st offence 100 fine 2nd offence start refused and 500 fine 2nd offence start refused and 100 fine STAGE RACE 1st offence 30’’penalisation in stage results 2nd offence start refused 22.
#
# - 4.1.035 Failing to attend official ceremonies 500 fine 100 fine 23.
#
# - 4.1.035 Non-compliant clothing during podium 500 fine 100 fine ceremony 24.
#
# - 4.1.035 Insult, threats, inappropriate Any licence holder 50 100 to 200 fine Any licence holder 50 to 200 fine behaviour 25.
#
# - 4.1.035 SPECIFIC ON DOWNHILL EVENTS 26.1 Rider no completing at least 2 Disqualification (DSQ) Disqualification (DSQ) training runs Disqualification (DSQ) Disqualification (DSQ) 26.2 Start training run below the start line Start refused Start refused 26.3 Rider no wearing protections imposed by the national federation 27.
#
# - 4.1.035 SPECIFIC ON ENDURO EVENTS 27.1 Rider without bike mark at the Not applicable 1’ penalization finish 1’ penalisation 27.2 Deliberate obstruction of the fastest rider 27.3 Feeding outside the feed/technical Disqualification (DSQ) assistance Zone 27.4 Changing any marked bicycle With permission from race control: 3 minutes component during a race without penalty permission from the race control.
#
# - 4.1.035 Late entries UCI World Cup cross-country, cross-country short N/A track, cross-country marathon, downhill and enduro: CHF 300 29.
#
# - 4.1.035 LITTERING 1st offence 250 fine 1st offence 100 fine 29.1 Rider or team disposing of waste 2nd offence 500 fine and disqualification (DSQ) 2nd offence 200 fine and disqualification (DSQ) or other objects outside of feed and technical assistance areas or organised littering zone.
#
# - 4.1.035 29.2 Disposing of waste or other objects in a careless or dangerous manner.
#
# - 4.1.035 C E O NT N A T L IN C E H N A T M A P U .
#
# - 4.1.035 X R P a la n c g e / Elite H Elite F Elite U23* Junior XCE R T el e a a y m ** * Elite U23 Elite U23* Junior R T el e a a y m ** * 1 300 300 300 200 200 110 200 250 125 150 75 60 100 2 250 250 250 150 150 90 150 200 100 120 55 40 75 3 200 200 200 120 120 80 120 160 80 100 45 30 60 4 180 180 180 100 100 70 100 150 75 90 40 25 50 5 160 160 160 95 95 60 90 140 70 80 35 20 40 6 140 140 140 90 90 50 80 130 65 70 30 18 30 7 130 130 130 85 85 40 75 120 60 60 25 16 25 8 120 120 120 80 80 35 70 110 55 50 20 14 20 9 110 110 110 75 75 30 65 100 50 40 15 12 10 10 100 100 100 70 70 25 60 95 47 38 10 10 5 11 95 95 95 65 65 20 55 90 45 36 8 8 x 12 90 90 90 60 60 15 50 85 42 34 6 6 13 85 85 85 55 55 10 45 80 40 32 4 4 14 80 80 80 50 50 5 40 78 39 30 2 2 15 78 78 78 45 45 3 35 76 38 28 1 1 16 76 76 76 40 40 1 30 74 37 26 X x 17 74 74 74 38 38 x 25 72 36 24 18 72 72 72 36 36 20 70 35 22 19 70 70 70 34 34 15 68 34 20 20 68 68 68 32 32 10 66 33 18 21 66 66 66 30 30 x 64 32 16 22 64 64 64 28 28 62 31 14 23 62 62 62 26 26 60 30 12 24 60 60 60 24 24 58 28 10 25 58 58 58 22 22 56 26 8 26 56 56 56 20 20 54 24 6 27 54 54 54 18 18 52 22 5 28 52 52 52 16 16 50 20 4 29 50 50 50 14 14 48 18 3 30 45 45 48 13 13 46 16 2 31 40 40 46 12 12 44 14 x 32 35 35 44 11 11 42 12 33 30 30 42 10 10 40 10 34 25 25 41 9 9 38 9 35 20 20 40 8 8 36 8 36 15 15 39 7 7 34 7 37 10 10 38 6 6 32 6 38 5 5 37 5 5 30 5 39 x x 36 4 4 29 4 40 35 3 3 28 3 41 34 2** 2** 27 2** 42 33 26 43 32 25 44 31 24 45 30 23 46 29 22 47 28 21 48 27 20 49 26 19 50 25 18 51 24 17 52 23 16 53 22 15 54 21 14 55 20 13 56 19 12 57 18 11 58 17 10 59 16 9 60 15 8 61 5** 3** * en cas d'épreuve séparée / in case of split event ** nombre de points pour chaque coureur classé / ** amount of points for each ranked rider *** les points ne sont pas nominatifs aux coureurs mais à la Nation / the points are not nominatif to the riders but to the Nation Classe 2 / COUPE du Classe 3 / MONDE XCE / Jeux XCO CHAMP.
#
# - 4.1.035 NATIONAUX H o r s C l a s s e / Junior / Classe 1 XCE WORLD CUP / régionaux / JUNIOR NATIONAL CHAMP.
#
# - 4.1.035 CHAMPIONNATS DU MONDE CHAMP.
#
# - 4.1.035 CONTINENTAUX COUPE DU MONDE NATIONAUX Classe 3 WORLD CHAMPIONSHIPS CONTINENTAL CHAMP.
#
# - 4.1.035 WORLD CUP NATIONAL CHAMP.
#
# - 4.1.035 Hors Classe / SNOW Classe 1 BIKE UCI Classe 3 Continental Series / UCI WORLD Rang / Elite Juniors Elite Juniors Elite Juniors Elite Elite Elite Place 1 150 50 100 35 90 30 60 30 10 2 120 40 90 30 70 25 40 20 6 3 100 35 70 25 60 20 30 15 4 4 90 30 60 20 50 18 25 12 2 5 80 25 50 18 40 16 20 10 1 6 70 20 40 16 35 15 18 8 7 60 18 30 14 30 14 16 6 8 50 16 20 12 27 13 14 4 9 40 14 10 10 24 12 12 2 10 38 12 5 8 22 11 10 1 11 36 10 20 10 8 12 34 9 18 9 6 13 32 8 16 8 4 14 30 7 14 7 2 15 28 6 12 6 1 16 26 5 10 5 17 24 4 9 4 18 22 3 8 3 19 20 2 7 2 20 18 1 6 1 21 16 5 22 14 4 23 12 3 24 10 2 25 8 1 ** For the final round, no world cup points will be awared for the qualifying round, those world cup points will be given to the final instead.
#
# - 4.1.035 CHAMPIONNATS DU MONDE COUPE DU MONDE CHAMP.
#
# - 4.1.035 WORLD CHAMPIONSHIPS WORLD CUPS NAT.
#
# ✅ CSV oluşturuldu: uci_rules_en_chunks.csv
# Toplam satır: 517

# %%
import pandas as pd

INPUT_CSV = "uci_rules_en_chunks.csv"

df = pd.read_csv(INPUT_CSV, encoding="utf-8")

df.head()
# Out:
#          uid article_id                                          source_en
# 0  4.1.004_1    4.1.004  Except in the UCI World Championships, Contine...
# 1  4.1.004_2    4.1.004  Separate under 23 XCO UCI World Cup events are...
# 2  4.1.004_3    4.1.004  The first 5 men under 23 and the first 5 women...
# 3  4.1.004_4    4.1.004  All other under 23 riders must race the UCI Wo...
# 4  4.1.004_5    4.1.004  Riders benefitting from the injury status shou...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   uid         517 non-null    object
#  1   article_id  517 non-null    object
#  2   source_en   517 non-null    object
# dtypes: object(3)
# memory usage: 12.2+ KB
# uid           0
# article_id    0
# source_en     0
# dtype: int64

# %%
# !pip install -U google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (0.8.5)
# Collecting google-generativeai
#   Downloading google_generativeai-0.8.6-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.43.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.12.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (2.32.4)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.11.12)
# Downloading google_generativeai-0.8.6-py3-none-any.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.1/155.1 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: google-generativeai
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.8.5
#     Uninstalling google-generativeai-0.8.5:
#       Successfully uninstalled google-generativeai-0.8.5
# Successfully installed google-generativeai-0.8.6

# %%
def call_teacher_llm(text):
    response = client.chat.completions.create(
        model="gemini-2.5-flash", # Güncellenmiş model adı
        messages=[
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": text}
        ],
        temperature=0.1
    )

    return response.choices[0].message.content.strip()

# %%
import google.generativeai as genai
from google.colab import userdata

api_key = userdata.get('Gemini')
genai.configure(api_key=api_key)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

response = model.generate_content("Hello, just say OK")

print(response.text)
# Out:
# OK

# %%
test_prompt = """
You are a professional technical translator.

Translate the following text to Turkish:

Riders shall wear helmets at all times.
"""

response = model.generate_content(test_prompt)
print(response.text)
# Out:
# Sürücülerin her zaman kask takması zorunludur.

# %%
SYSTEM_PROMPT = """
You are a professional technical translator specialized in UCI cycling regulations.

IMPORTANT:
You MUST strictly follow the terminology rules below.
Do NOT simplify legal language.
Do NOT replace modal verbs with future tense.
Violations are not allowed.

Your task:
- Translate the given regulatory text from English to Turkish
- Preserve ALL technical and legal terminology accurately
- Use formal regulatory Turkish (resmi yönetmelik dili)
- Do NOT simplify, summarize, or paraphrase
- Keep the sentence structure as close as possible to the original
- Maintain consistency across fragments belonging to the same article

Critical terminology rules (MANDATORY):
- The following terminology MUST be used exactly as specified
- Do NOT invent alternatives
- Respect notes and forbidden usages strictly

Terminology glossary and usage rules:

Institutional / Organizational:
- "UCI (Union Cycliste Internationale)" → "UCI (Uluslararası Bisiklet Birliği)"
  Rule: Write full form on first occurrence, then use "UCI" only
- "National Federation" → "Ulusal Federasyon"
- "World Cup" → "Dünya Kupası" (proper name preserved)
- "World Championships" → "Dünya Şampiyonası"

Legal / Regulatory:
- "Regulations" → "Yönetmelik" (DO NOT use "Kurallar")
- "Rules amendments" → "Kural değişiklikleri"
- "Memorandum" → "Memorandum (Duyuru)"
- "Entry into force" → "Yürürlüğe giriş"
- "Eligibility" → "Uygunluk"
- "Licence holder" → "Lisanslı sporcu"
- "Sanction" → "Yaptırım" (DO NOT confuse with "Ceza")
- "Penalty" → "Ceza"
- "Disqualification (DSQ)" → "Diskalifiye (DSQ)"
- "Suspension" → "Men cezası"

Modal / Legal language (VERY IMPORTANT):
- "Shall" → "-mek zorundadır" (NEVER use "-acaktır")
- "Must" → "-melidir"
- "May" → "-ebilir"
- "In accordance with" → "-e uygun olarak"
- "Subject to" → "-e tabi olarak"

Athletes and categories:
- "Rider" → "Sporcu" (NEVER use "Sürücü")
- "Athlete" → "Sporcu"
- "Elite" → "Elit"
- "Junior" → "Gençler"
- "Age category" → "Yaş kategorisi"
- "Under 23" → "23 yaş altı"

Events and competition:
- "Event" → "Yarış / Organizasyon" (choose based on context)
- "Competition" → "Yarışma" (DO NOT confuse with Event)
- "Category" → "Kategori" (DO NOT use "Sınıf")
- "Participation" → "Katılım"

Disciplines and formats:
- "Mountain Bike (MTB)" → "Dağ Bisikleti (MTB)" (explain on first use)
- "Cross-country (XCO)" → "Kros-Kantri (XCO)"
- "Downhill (DHI)" → "İniş (DHI)"
- "Short Track (XCC)" → "Kısa Parkur (XCC)"

Race procedures:
- "Course" → "Parkur" (NEVER use "Pist")
- "Start order" → "Start sıralaması"
- "Qualification" → "Eleme"
- "Heat" → "Seri"

Officials:
- "Commissaire" → "Hakem" (UCI standard)
- "Chief Commissaire" → "Başhakem"
- "Jury" → "Hakem Kurulu"

Output rules:
- Output ONLY the translated Turkish text
- No explanations, no comments, no markdown
"""

# %%
from tqdm import tqdm
import time

# %%
def call_teacher_llm(text):
    prompt = f"""
{SYSTEM_PROMPT}

Text to translate:
{text}
"""
    response = model.generate_content(prompt)
    return response.text.strip()

# %%
INPUT_CSV = "uci_rules_en_chunks.csv"

df = pd.read_csv(INPUT_CSV, encoding="utf-8")

df = df[df["source_en"].notna()].reset_index(drop=True)

df.head()
# Out:
#          uid article_id                                          source_en
# 0  4.1.004_1    4.1.004  Except in the UCI World Championships, Contine...
# 1  4.1.004_2    4.1.004  Separate under 23 XCO UCI World Cup events are...
# 2  4.1.004_3    4.1.004  The first 5 men under 23 and the first 5 women...
# 3  4.1.004_4    4.1.004  All other under 23 riders must race the UCI Wo...
# 4  4.1.004_5    4.1.004  Riders benefitting from the injury status shou...

# %%
TEST_N = 3  # önce 3 satır yeter

test_outputs = []

for i, row in df.head(TEST_N).iterrows():
    uid = row["uid"]
    text = row["source_en"]

    print("="*80)
    print(f"UID: {uid}")
    print("SOURCE (EN):")
    print(text)
    print("\n--- TRANSLATING ---\n")

    tr_text = "" # Initialize tr_text
    for attempt in range(2):  # 1 retry hakkı
        try:
            tr_text = call_teacher_llm(text)
            print("TARGET (TR):")
            print(tr_text)
            break
        except Exception as e:
            if attempt == 1:
                print(f"❌ FAIL | uid={uid} | {e}")
            else:
                print(f"⚠️ Retry for uid={uid} after error: {e}")
                time.sleep(2) # Wait before retrying

    test_outputs.append({
        "uid": uid,
        "article_id": row["article_id"],
        "source_en": text,
        "target_tr": tr_text
    })

    time.sleep(1)
# Out:
# ================================================================================
# UID: 4.1.004_1
# SOURCE (EN):
# Except in the UCI World Championships, Continental Championships, UCI Mountain Bike Continental Series and, at the discretion of national federations, National Championships, under 23 men and women can ride the events for elite men and women respectively, even if a separate event is being run for under 23 riders.
#
# --- TRANSLATING ---
#
# TARGET (TR):
# UCI Dünya Şampiyonası, Kıta Şampiyonaları, UCI Dağ Bisikleti Kıta Serileri ve Ulusal Federasyonların takdirine bağlı olarak Ulusal Şampiyonalar haricinde, 23 yaş altı erkek ve kadın sporcular, 23 yaş altı sporcular için ayrı bir yarış düzenleniyor olsa bile, sırasıyla elit erkekler ve kadınlar için düzenlenen yarışlara katılabilir.
# ================================================================================
# UID: 4.1.004_2
# SOURCE (EN):
# Separate under 23 XCO UCI World Cup events are organised for men and women.
#
# --- TRANSLATING ---
#
# TARGET (TR):
# Erkekler ve kadınlar için ayrı 23 yaş altı Kros-Kantri (XCO) UCI (Uluslararası Bisiklet Birliği) Dünya Kupası yarışları düzenlenmektedir.
# ================================================================================
# UID: 4.1.004_3
# SOURCE (EN):
# The first 5 men under 23 and the first 5 women under 23 of the last UCI XCO individual ranking of the preceding year can decide whether they want to race the entire UCI World Cup season as elite or under 23.
#
# --- TRANSLATING ---
#
# TARGET (TR):
# Bir önceki yılın son UCI Kros-Kantri (XCO) bireysel sıralamasında ilk 5'te yer alan 23 yaş altı erkek sporcular ile ilk 5'te yer alan 23 yaş altı kadın sporcular, tüm UCI Dünya Kupası sezonunda elit kategorisinde mi yoksa 23 yaş altı kategorisinde mi yarışmak istediklerine karar verebilirler.

# %%
translated_rows = []

for _, row in tqdm(df.iterrows(), total=len(df)):
    uid = row["uid"]
    text = row["source_en"]

    # Daha uzun bir bekleme süresi ile birden fazla deneme hakkı
    for attempt in range(5):  # 4 retry hakkı
        try:
            tr_text = call_teacher_llm(text)

            translated_rows.append({
                "uid": uid,
                "article_id": row["article_id"],
                "source_en": text,
                "target_tr": tr_text
            })

            time.sleep(1)  # Başarılı çağrılar arasında daha uzun bekleme
            break

        except Exception as e:
            print(f"⚠️ Hata alındı: {e}")
            if attempt < 4: # Son deneme değilse tekrar dene
                # API hatasından 'retry-after' süresini çıkarmaya çalış
                retry_after_match = re.search(r'Please retry in (\d+\.\d+)s', str(e))
                if retry_after_match:
                    wait_time = float(retry_after_match.group(1)) + 1 # Biraz daha ekle
                    print(f"Retrying for uid={uid} after {wait_time:.2f} seconds...")
                    time.sleep(wait_time)
                else:
                    # Varsayılan olarak daha uzun bekleme
                    print(f"Retrying for uid={uid} after 10 seconds (attempt {attempt + 1})...")
                    time.sleep(10)
            else:
                print(f"❌ FAIL | uid={uid} | Maksimum deneme hakkı aşıldı: {e}")
# Out:
#   0%|          | 0/517 [00:00<?, ?it/s]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 810.89ms
# ⚠️ Hata alındı: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 6.057789284s.
# Retrying for uid=4.1.004_1 after 7.06 seconds...
#   0%|          | 0/517 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipython-input-4104682762.py in <cell line: 0>()
#       9         try:
# ---> 10             tr_text = call_teacher_llm(text)
#      11
#
# /tmp/ipython-input-1886063509.py in call_teacher_llm(text)
#       7 """
# ----> 8     response = model.generate_content(prompt)
#       9     return response.text.strip()
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     130
# --> 131         return wrapped_func(*args, **kwargs)
#     132
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     293             )
# --> 294             return retry_target(
#     295                 target,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     155             # defer to shared logic for handling errors
# --> 156             next_sleep = _retry_error_helper(
#     157                 exc,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     213         )
# --> 214         raise final_exc from source_exc
#     215     if on_error_fn is not None:
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     129
# --> 130             return func(*args, **kwargs)
#     131
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      74         try:
# ---> 75             return callable_(*args, **kwargs)
#      76         except grpc.RpcError as exc:
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#    1160             if response.status_code >= 400:
# -> 1161                 raise core_exceptions.from_http_response(response)
#    1162
#
# TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 6.057789284s.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4104682762.py in <cell line: 0>()
#      28                     wait_time = float(retry_after_match.group(1)) + 1 # Biraz daha ekle
#      29                     print(f"Retrying for uid={uid} after {wait_time:.2f} seconds...")
# ---> 30                     time.sleep(wait_time)
#      31                 else:
#      32                     # Varsayılan olarak daha uzun bekleme
#
# KeyboardInterrupt:

# %%
for i in translated_rows:
  print(translated_rows(i))
  print("\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4100851428.py in <cell line: 0>()
#       1 for i in translated_rows:
# ----> 2   print(translated_rows(i))
#       3   print("\n")
#
# TypeError: 'list' object is not callable
